# %%
import numpy as np
import pandas as pd

import holoviews as hv
hv.extension('bokeh')
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.bk-hbox {
#     display: flex;
#     justify-content: center;
# }
#
# div.bk-hbox div.bk-plot {
#     padding: 8px;
# }
#
# div.bk-hbox div.bk-data-table {
#     padding: 20px;
# }
#
# div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
# ...

# %%
df = pd.read_csv('./master.csv')
df = df[[
 'material',
 'stress_indicator',
 'sample',
 'file_tag',
 'bends',
 'primary_position',
 'frequency',
 'temperature',
 'pressure',
 'bend_to_break',
 'break_location',
 'prim_sec_amp',
 'prim_sec_phi',
 'prim_rec_amp',
 'prim_rec_phi',
 'sec_rec_amp',
 'sec_rec_phi',
 'sec_harm_db',
 'rec_harm_db'
]]
df.head()
# Out:
#   material stress_indicator         sample       file_tag  bends  \
# 0       CS                M  TU20180416-01  20180416-0001    0.0
# 1       CS                M  TU20180416-01  20180416-0001    0.0
# 2       CS                M  TU20180416-01  20180416-0002    0.0
# 3       CS                M  TU20180416-01  20180416-0002    0.0
# 4       CS                M  TU20180416-01  20180416-0003    0.0
#
#    primary_position  frequency  temperature  pressure  bend_to_break  \
# 0              18.0         45         19.7      1615          576.0
# 1              18.0         45         19.7      1615          576.0
# 2              15.0         45         19.7      1615          576.0
# 3              15.0         45         19.7      1615          576.0
# 4              12.0         45         19.7      1615          576.0
#
#    break_location  prim_sec_amp  prim_sec_phi  prim_rec_amp  prim_rec_phi  \
# 0             5.0      0.005510      0.552248      0.012669     -2.277704
# ...

# %%
list(df.columns)
# Out:
# ['file_tag',
#  'test_no',
#  'sample',
#  'bends',
#  'primary_position',
#  'frequency',
#  'temperature',
#  'material',
#  'stress_indicator',
#  'pressure',
#  'bend_to_break',
#  'break_location',
#  'prim_sec_amp',
#  'prim_sec_phi',
#  'prim_rec_amp',
#  'prim_rec_phi',
#  'sec_rec_amp',
#  'sec_rec_phi',
#  'sec_harm_db',
#  'rec_harm_db']

# %%
# %opts Curve [logx=False, logy=False, width=400, height=300]
# %opts Curve [show_legend=True, show_grid=True, tools=['hover']]
# %opts Scatter (size=4)

def doit(df, sample):
    df = df[df['sample'] == sample]
    material = df.material.iloc[0]
    stress = df.stress_indicator.iloc[0]
    breaking_loc = df.break_location.iloc[0]
    cols = [
        'prim_sec_amp',
        'sec_harm_db',
    ]

    ctot = None
    for col in cols:
        c = None
        for pos in sorted(df.primary_position.unique()):
            dfx = df[df.primary_position == pos]
            c_this = hv.Curve((dfx.bends, dfx[col]), label=f'{pos}', kdims=[f'Bends "{material}-{stress}-{breaking_loc}" {sample}'], vdims=[col])
            c_this *= hv.Scatter(c_this)
            if c is None:
                c = c_this
            else:
                c = c * c_this
        if ctot is None:
            ctot = c
        else:
            ctot += c
    ctot.cols(2)
    
    return ctot
for samp in df['sample'].unique():
    display(doit(df, samp))
# Out:
# :Layout
#    .Overlay.I  :Overlay
#       .Curve.A_6_full_stop_0    :Curve   [Bends "CS-M-5.0" TU20180416-01]   (prim_sec_amp)
#       .Scatter.A_6_full_stop_0  :Scatter   [Bends "CS-M-5.0" TU20180416-01]   (prim_sec_amp)
#       .Curve.A_9_full_stop_0    :Curve   [Bends "CS-M-5.0" TU20180416-01]   (prim_sec_amp)
#       .Scatter.A_9_full_stop_0  :Scatter   [Bends "CS-M-5.0" TU20180416-01]   (prim_sec_amp)
#       .Curve.A_12_full_stop_0   :Curve   [Bends "CS-M-5.0" TU20180416-01]   (prim_sec_amp)
#       .Scatter.A_12_full_stop_0 :Scatter   [Bends "CS-M-5.0" TU20180416-01]   (prim_sec_amp)
#       .Curve.A_15_full_stop_0   :Curve   [Bends "CS-M-5.0" TU20180416-01]   (prim_sec_amp)
#       .Scatter.A_15_full_stop_0 :Scatter   [Bends "CS-M-5.0" TU20180416-01]   (prim_sec_amp)
#       .Curve.A_18_full_stop_0   :Curve   [Bends "CS-M-5.0" TU20180416-01]   (prim_sec_amp)
#       .Scatter.A_18_full_stop_0 :Scatter   [Bends "CS-M-5.0" TU20180416-01]   (prim_sec_amp)
# ...

# %%
df.count()
# Out:
# material            1698
# stress_indicator    1698
# sample              1698
# file_tag            1698
# bends               1698
# primary_position    1698
# frequency           1698
# temperature         1698
# pressure            1698
# bend_to_break       1698
# break_location      1364
# prim_sec_amp        1698
# prim_sec_phi        1698
# prim_rec_amp        1698
# prim_rec_phi        1698
# sec_rec_amp         1698
# sec_rec_phi         1698
# sec_harm_db         1698
# rec_harm_db         1698
# dtype: int64
